# %%
import pandas as pd
from IPython.display import Image
import cv2
import numpy as np
import imutils

# %%
from main import Image, rotate_img, rotated_segment

# %%
image = Image('data/1.jpg')

# %%
from matplotlib import pyplot as plt
plt.imshow(image.img)

# %%
plt.imshow(np.array(image.img)*(-1)+255)

# %%
plt.imshow(rotate_img(image.img, 77))

# %%
plt.imshow(rotated_segment(img=image.img, deg=218, widthPixels=20, center=image.center))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17560\4107703667.py in <module>
# ----> 1 plt.imshow(rotated_segment(img=image.img, deg=218, widthPixels=20, center=image.center))
#
# ~\PycharmProjects\radialSegmentation\main.py in rotated_segment(img, deg, widthPixels, center)
#      21     imgr = rotate_img(img, deg)
#      22     mask = np.zeros(imgr.shape, dtype='uint8')
# ---> 23     cv2.rectangle(mask, (center[0], center[1] - (widthPixels / 2)), (center[0] + 25000000, center[1] + (widthPixels / 2)), (255,255,255), -1)
#      24     return np.where(mask, imgr, np.zeros(imgr.shape, dtype='uint8'))
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Sequence item with index 1 has a wrong type
# >  - Can't parse 'pt1'. Sequence item with index 1 has a wrong type
# ...
